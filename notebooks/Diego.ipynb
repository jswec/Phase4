# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Standard Packages
import pandas as pd
import numpy as np
import string
import ssl
import re

# Statsmodels
import statsmodels.api as sm

# NLTK
from nltk import word_tokenize          
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer, TweetTokenizer         # Tweet Tokenizer!
from nltk import FreqDist
from nltk.corpus import stopwords
import nltk
# nltk.download('wordnet')

# Scikit-Learn
from sklearn.ensemble import RandomForestClassifier
from sklearn.dummy import DummyClassifier
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_score, GridSearchCV, train_test_split
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
df = pd.read_csv("data/tweets.csv")
df.columns = ['text', 'device', 'emotion']

# %%
df.head()
# Out:
#                                                 text              device  \
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs twe...              iPhone
# 1  @jessedee Know about @fludapp ? Awesome iPad/i...  iPad or iPhone App
# 2  @swonderlin Can not wait for #iPad 2 also. The...                iPad
# 3  @sxsw I hope this year's festival isn't as cra...  iPad or iPhone App
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa M...              Google
#
#             emotion
# 0  Negative emotion
# 1  Positive emotion
# 2  Positive emotion
# 3  Negative emotion
# 4  Positive emotion

# %%
### Deliniating between Google and Apple

google_tweets = ['Google', 'Other Google product or service', 'Andriod App', 'Andriod']
apple_tweets = ['Apple', 'Other Apple product or service', 'Apple App', 'iPhone', 'iPad', 'iPad or iPhone App']

### Creating a new column for google vs. apple vs. unknown

df['device_type'] = np.where(df['device'].isin(google_tweets), 'Google', np.where(df['device'].isin(apple_tweets), 'Apple', 'Unknown'))

### Dropping 'I can't tell' and 'Other' rows

# df = df[df['emotion'] != "I can't tell"]

### Dropping blank 'text' rows

df = df.dropna(subset=['text'])

# %%
pd.set_option('display.max_colwidth', None)

# %%
df[df.text.str.contains('#')].shape
# Out:
# (9086, 4)

# %%
df[~df.text.str.lower().str.contains('sxsw')]
# Out:
#                                                                                                                                            text  \
# 770                                                             Google to Launch Major New Social Network Called Circles, Possibly Today {link}
# 794                                       Google to Launch Major New Social Network Called Circles, Possibly Today @mention {link} via @mention
# 1142                                                                            ‰ÛÏ@mention The 10 most dangerous IPhone apps. {link}  @mention
# 2431                                                                    Extra iPad 2 for sale in Austin convention center who wants one? {link}
# 2713                                                                             Get in the season with Clover Touch:\r{link} #Games #STPATRICK
# 3482  GENIUS behind Google Circles.\r¡á¾_Î¾Ð¡__Š___ÔÈÏ_ãŒöÝÇÜŠ¼¼\rReal Life Social Graph Network v2 \rView documents by Paul Adams {link}
# 4920                                                          Download of the Day: Lonely Planet Austin, Free For a Limited Time {link} #iPhone
# 5025                                                                                                                                RT @mention
#
#                                device                             emotion  \
# 770                            Google                    Positive emotion
# 794                               NaN  No emotion toward brand or product
# 1142                              NaN  No emotion toward brand or product
# 2431                              NaN  No emotion toward brand or product
# 2713                              NaN  No emotion toward brand or product
# 3482  Other Google product or service                    Positive emotion
# 4920                              NaN  No emotion toward brand or product
# 5025                              NaN  No emotion toward brand or product
#
#      device_type
# 770       Google
# 794      Unknown
# 1142     Unknown
# 2431     Unknown
# 2713     Unknown
# 3482      Google
# 4920     Unknown
# 5025     Unknown

# %%
df.emotion.value_counts()
# Out:
# No emotion toward brand or product    5388
# Positive emotion                      2978
# Negative emotion                       570
# I can't tell                           156
# Name: emotion, dtype: int64

# %%
df.shape
# Out:
# (9092, 4)

# %%
r = r'[^\w\s](?:\s*#[a-zA-Z]+)+(?:\s*[^\w\s])?'
r2 = r'#.*?(?=\s|$)'
df.text.str.findall(r2)
# Out:
# 0          [#RISE_Austin,, #SXSW.]
# 1                          [#SXSW]
# 2                  [#iPad, #SXSW.]
# 3                          [#sxsw]
# 4                         [#SXSW:]
#                    ...
# 9088                       [#SXSW]
# 9089    [#sxsw, #google, #circles]
# 9090          [#sxsw, #health2dev]
# 9091                      [#SXSW.]
# 9092                       [#SXSW]
# Name: text, Length: 9092, dtype: object

# %%
df[df.device_type == 'Unknown']
# Out:
#                                                                                                                                                    text  \
# 5          @teachntech00 New iPad Apps For #SpeechTherapy And Communication Are Showcased At The #SXSW Conference http://ht.ly/49n4M #iear #edchat #asd
# 7            #SXSW is just starting, #CTIA is around the corner and #googleio is only a hop skip and a jump from there, good time to be an #android fan
# 10                               Excited to meet the @samsungmobileus at #sxsw so I can show them my Sprint Galaxy S still running Android 2.1.   #fail
# 11                    Find &amp; Start Impromptu Parties at #SXSW With @HurricaneParty http://bit.ly/gVLrIn I can't wait til the Android app comes out.
# 12                Foursquare ups the game, just in time for #SXSW http://j.mp/grN7pK) - Still prefer @Gowalla by far, best looking Android app to date.
# ...                                                                                                                                                 ...
# 9087                                                @mention Yup, but I don't have a third app yet. I'm on Android, any suggestions? #SXSW CC: @mention
# 9089                      Wave, buzz... RT @mention We interrupt your regularly scheduled #sxsw geek programming with big news {link}  #google #circles
# 9090  Google's Zeiger, a physician never reported potential AE. Yet FDA relies on physicians. &quot;We're operating w/out data.&quot; #sxsw #health2dev
# 9091       Some Verizon iPhone customers complained their time fell back an hour this weekend.  Of course they were the New Yorkers who attended #SXSW.
# 9092                                           ŒÏ¡ŽÏàŠü_‹Ê‹Î‹Ò‹£‹Á‹ââ‹_‹£‹‹â_‹ÛâRT @mention Google Tests ‰ÛÏCheck-in Offers‰Û At #SXSW {link}
#
#            device                             emotion device_type
# 5             NaN  No emotion toward brand or product     Unknown
# 7         Android                    Positive emotion     Unknown
# 10        Android                    Positive emotion     Unknown
# 11    Android App                    Positive emotion     Unknown
# 12    Android App                    Positive emotion     Unknown
# ...           ...                                 ...         ...
# 9087          NaN  No emotion toward brand or product     Unknown
# 9089          NaN  No emotion toward brand or product     Unknown
# 9090          NaN  No emotion toward brand or product     Unknown
# 9091          NaN  No emotion toward brand or product     Unknown
# 9092          NaN  No emotion toward brand or product     Unknown
#
# [5960 rows x 4 columns]

# %% [markdown]
# ### Making X and y

# %%
X = df.drop('emotion', axis=1)
y = df['emotion']

# %% [markdown]
# ### Train, Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1337)

# %%
X.device_type.value_counts()
# Out:
# Unknown    5813
# Apple      2402
# Google      721
# Name: device_type, dtype: int64

# %%
### Creating a function that removes words that begin with @

def remove_at(text):
    text = text.split()
    text = [word for word in text if not word.startswith('@')]
    text = ' '.join(text)
    return text

### Creating a function that makes all text lowercase

def lower_case(text):
    text = text.lower()
    return text

### Creating a function that removes all punctuation

def remove_punctuation(text):
    text = text.translate(str.maketrans('', '', string.punctuation))
    return text

### Creating a function that removes all stopwords

def remove_stopwords(text):
    stop_words = set(stopwords.words('english'))
    text = text.split()
    text = [word for word in text if not word in stop_words]
    text = ' '.join(text)
    return text

### Creating a function that removes words that contain characters like ‰ÛÏ or ‰ÛÒ or ‰ÛÓ or ‰ÛÒ

def remove_characters(text):
    text = text.split()
    text = [word for word in text if not word.startswith('‰ÛÏ') and not word.startswith('‰ÛÒ') and not word.startswith('‰ÛÓ') and not word.startswith('‰ÛÒ')]
    text = ' '.join(text)
    return text

### Creating a function that lemmatizes words

def lemmatize(text):
    lemmatizer = WordNetLemmatizer()
    text = text.split()
    text = [lemmatizer.lemmatize(word) for word in text]
    text = ' '.join(text)
    return text

### Creating a function that removes all numbers

def remove_numbers(text):
    text = ''.join([i for i in text if not i.isdigit()])
    return text

### Creating a function takes the tokenized text and returns a string of words

def tokenize_to_string(text):
    tknzr = TweetTokenizer()
    text = tknzr.tokenize(text)
    text = ' '.join(text)
    return text

### Creating a function that combines all of the above functions

def clean_text(text):
    text = remove_at(text)
    text = lower_case(text)
    text = remove_punctuation(text)
    text = remove_stopwords(text)
    text = remove_characters(text)
    text = lemmatize(text)
    text = remove_numbers(text)
    text = tokenize_to_string(text)
    return text

# %%
### Applying the 'lemmatize_text' function to the 'text' column

X_train['text'] = X_train['text'].apply(lemmatize_text)

# %%
apple_terms = ['apple', 'ipad', 'iphone']

google_terms = ['']

# %%
df[200:250]
# Out:
#                                                                                                                                                text  \
# 201          U = smart 4 packing an extra :) RT @mention On my way to sunny Austin for #sxsw! Extra iPhone in stow, just in case. @mention @mention
# 202              Wonder if 4sqwill attempt to block GoWalla cross-checkins, the way Facebook blocked Google's contacts connections.  #sxsw #lbsWars
# 203                                                                   #SXSW day 5 at the #apple store and there's still a line...and growing {link}
# 204                                                            Check out 5 Steps to Bulletproof UX Strategy at SXSW\r{link} #SXSW #rhjr_ux5  {link}
# 205                                           Wandering 6th street with the girls. Stopped for ceviche, mojitos, apple juice &amp; ice cream. #sxsw
# 206         If you're a band at #SXSW and want to share a track with your Audience from stage, use FrostWire for Android if there's Wi-Fi available
# 207                               We've got a busy week ahead: Our new book on #Google Apps will be available on Amazon &amp; we're attending #SXSW
# 208                                  I believe a few went to Aussies at #sxsw RT @mention iPad 2 Sold Out, 70% Went to New Buyers [REPORT] - {link}
# 209                     ‰ÛÏ@mention A Google Spreadsheet of over 270 parties at #SXSW this year O_O {link} @mention Plan on going to #SXSW Party on
# 210                         There was a guy in line for Apple's pop-up store on Sixth Street in Austin. &quot;I'm that guy,&quot; he told me. #sxsw
# 211                                                        if u have a iPhone you don't need a car'-use zimride etc to share rides #sxsw #shareable
# 212                                                                     I've seen a lot of tablets here, every single one of them is an iPad. #SXSW
# 213           Receiving a lot of @mention messages telling me I'm sexy in response to my post looking to meet fellow Christian iPhone devs at #sxsw
# 214  Picked up a Mophie battery case 4 my iPhone in prep for #SXSW. Not lugging around a laptop &amp; only using my phone was a huge win last year.
# 215                            Now thats a NEWS :P RT@mention Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxsw
#
# 250     I came in and left #sxsw with my iPhone playing the same song, chosen at random: Skream's Listening to the Records on my wall. Appropriate.
#
#                               device                             emotion  \
# 201                              NaN  No emotion toward brand or product
# 202                              NaN  No emotion toward brand or product
# 203                            Apple                    Positive emotion
# 204                              NaN  No emotion toward brand or product
# 205                              NaN  No emotion toward brand or product
# 206                      Android App                    Positive emotion
# 207                              NaN  No emotion toward brand or product
# 208                              NaN  No emotion toward brand or product
# 209                              NaN  No emotion toward brand or product
# 210                              NaN  No emotion toward brand or product
# 211               iPad or iPhone App                    Positive emotion
# 212                              NaN  No emotion toward brand or product
# 213                              NaN  No emotion toward brand or product
# 214                           iPhone                    Positive emotion
# 215                              NaN  No emotion toward brand or product
# 216                              NaN  No emotion toward brand or product
# 217  Other Google product or service                    Positive emotion
# 218                              NaN  No emotion toward brand or product
# 219               iPad or iPhone App                    Positive emotion
# 220                            Apple                    Positive emotion
# 221                              NaN  No emotion toward brand or product
# 222                              NaN  No emotion toward brand or product
# 223               iPad or iPhone App                    Positive emotion
# 224                              NaN  No emotion toward brand or product
# 225                              NaN  No emotion toward brand or product
# 226                              NaN  No emotion toward brand or product
# 227                              NaN  No emotion toward brand or product
# 228                              NaN  No emotion toward brand or product
# 229                              NaN  No emotion toward brand or product
# 230                              NaN  No emotion toward brand or product
# 231                              NaN  No emotion toward brand or product
# 232                              NaN  No emotion toward brand or product
# 233                           iPhone                    Negative emotion
# 234                             iPad                    Positive emotion
# 235                              NaN  No emotion toward brand or product
# 236                           iPhone                    Negative emotion
# 237                              NaN                        I can't tell
# 238                              NaN  No emotion toward brand or product
# 239                              NaN  No emotion toward brand or product
# 240                            Apple                    Positive emotion
# 241                              NaN  No emotion toward brand or product
# 242                              NaN  No emotion toward brand or product
# 243                              NaN  No emotion toward brand or product
# 244                             iPad                    Positive emotion
# 245                           Google                    Positive emotion
# 246                              NaN  No emotion toward brand or product
# 247                              NaN  No emotion toward brand or product
# 248                              NaN  No emotion toward brand or product
# 249                              NaN  No emotion toward brand or product
# 250                              NaN  No emotion toward brand or product
#
#     device_type
# 201     Unknown
# 202     Unknown
# 203       Apple
# 204     Unknown
# 205     Unknown
# 206     Unknown
# 207     Unknown
# 208     Unknown
# 209     Unknown
# 210     Unknown
# 211       Apple
# 212     Unknown
# 213     Unknown
# 214       Apple
# 215     Unknown
# 216     Unknown
# 217      Google
# 218     Unknown
# 219       Apple
# 220       Apple
# 221     Unknown
# 222     Unknown
# 223       Apple
# 224     Unknown
# 225     Unknown
# 226     Unknown
# 227     Unknown
# 228     Unknown
# 229     Unknown
# 230     Unknown
# 231     Unknown
# 232     Unknown
# 233       Apple
# 234       Apple
# 235     Unknown
# 236       Apple
# 237     Unknown
# 238     Unknown
# 239     Unknown
# 240       Apple
# 241     Unknown
# 242     Unknown
# 243     Unknown
# 244       Apple
# 245      Google
# 246     Unknown
# 247     Unknown
# 248     Unknown
# 249     Unknown
# 250     Unknown
